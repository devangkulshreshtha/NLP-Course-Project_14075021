# %%
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential, Model
from keras.layers import Dense, Embedding, Dropout, merge
from keras.layers import LSTM,Bidirectional,GRU,SimpleRNN
import pandas as pd
from keras.layers import Conv2D, MaxPooling2D, Input

import tensorflow as tf
from keras.layers import Conv1D, GlobalMaxPooling1D,GlobalAveragePooling1D,MaxPooling1D, AveragePooling1D
from scipy.stats import pearsonr
from sklearn.cross_validation import train_test_split
# Out:
# Using Theano backend.

# %%
import keras.backend as K

def pearson(X,Y):
    #return K.mean(K.abs(y_true-y_pred))
    if K.sum(X)==0:return 0
    n = K.sum(X)/K.mean(X)
    if n==0:return 0
    num = K.sum(X*Y) - K.sum(X)*K.sum(Y)/n
    den = (K.sum(X*X) - K.square(K.sum(X))/n)*(K.sum(Y*Y) - K.square(K.sum(Y))/n)
    den = K.sqrt(den)
    if den==0 : return 0
    return num/den

def pearson1(X,Y):
    #return K.mean(K.abs(y_true-y_pred))
    if K.sum(X)==0:return 0
    n = K.sum(X)/K.mean(X)
    if n==0:return 0
    num = K.sum(X*Y) - K.sum(X)*K.sum(Y)/n
    den = (K.sum(X*X) - K.square(K.sum(X))/n)*(K.sum(Y*Y) - K.square(K.sum(Y))/n)
    den = K.sqrt(den)
    if den==0 : return 0
    return -1 * num/den

# %% [markdown]
# # prepare train, dev, test data

# %%
emotions = ['sadness']
x_train_1, y_train, x_test_1, y_test, x_train_2, x_test_2 = {},{},{},{},{},{}
for emotion in emotions : 
    
    x1t = np.load('../intermediates/train/'+emotion+'/X_'+emotion+'.npy')
    x2t = np.load('../intermediates/train/'+emotion+'/lexicon.npy')
    x3t = np.load('../intermediates/train/'+emotion+'/train_'+emotion+'.npy')
    yt = np.load('../intermediates/train/'+emotion+'/labels.npy')
    x1d = np.load('../intermediates/val/'+emotion+'/X_'+emotion+'_dev.npy')
    x2d = np.load('../intermediates/val/'+emotion+'/lexicon.npy')
    x3d = np.load('../intermediates/val/'+emotion+'/dev_'+emotion+'.npy')
    yd = np.load('../intermediates/val/'+emotion+'/labels.npy')    
    x1te = np.load('../intermediates/test/'+emotion+'/X_'+emotion+'.npy')
    x2te = np.load('../intermediates/test/'+emotion+'/lexicon.npy')
    x3te = np.load('../intermediates/test/'+emotion+'/test_'+emotion+'.npy')
    yte = np.load('../intermediates/test/'+emotion+'/labels.npy')
    
    x1t = np.concatenate([x1t,x2t], axis=1)
    x1d = np.concatenate([x1d,x2d], axis=1)
    x1te = np.concatenate([x1te,x2te], axis=1)
    
    x1t = np.concatenate([x1t,x1d], axis=0)
    x3t = np.concatenate([x3t,x3d], axis=0)
    yt = np.concatenate([yt,yd], axis=0)
    
    x_train_1[emotion] = x1t
    y_train[emotion] = yt
    x_test_1[emotion] = x1te
    y_test[emotion] = yte
    x_train_2[emotion] = x3t
    x_test_2[emotion] = x3te
    print emotion + ': ', x1t.shape, yt.shape, x1te.shape, yte.shape, x3t.shape, x3te.shape
# Out:
# sadness:  (860, 443) (860,) (673, 443) (673,) (860, 50, 400) (673, 50, 400)

# %% [markdown]
# # ensemble of feed-forward NN and CNN/LSTM for each emotion

# %% [markdown]
# ## anger

# %%
ypred = np.zeros(673)
for i in range(7) : 
    input1 = Input(shape=(443,))
    l1 = Dense(300, init='normal', activation='relu')(input1)
    #l1 = Dropout(p=0.2)(l1)
    l1 = Dense(150, init='normal', activation='relu')(l1)
    l1 = Dense(50, init='normal', activation='relu')(l1)
    #l1 = Dropout(p=0.2)(l1)
    l1 = Dense(20, init='normal', activation='relu')(l1)
    #o1 = Dense(1, init='normal')(l1)

    #cnn-lstm-1
    input2 = Input(shape=(50,400,))
    l2 = Conv1D(250,3,activation='relu')(input2)
    l2 = GlobalMaxPooling1D()(l2)
    #l2 = Dropout(p=0.3)(l2)
    l2 = Dense(125,activation='relu')(l2)
    l2 = Dense(50,activation='relu')(l2)
    #l2 = Dense(25,activation='relu')(l2)
    #o2 = Dense(1)(l2)

    merged_output = merge([l1, l2], mode='concat', concat_axis=-1)
    merged_output = Dense(25, activation='relu')(merged_output)
    merged_output = Dropout(p=0.2)(merged_output)
    predictions = Dense(1, activation='sigmoid')(merged_output)

    model = Model(input=[input1, input2], output=predictions)
    
    model.compile(loss='mae', optimizer='adam', metrics=[pearson])
    model.fit([x_train_1['sadness'], x_train_2['sadness']], y_train['sadness'], 
              nb_epoch=20, verbose=2, batch_size=8,
             )
    tmp = model.predict([x_test_1['sadness'], x_test_2['sadness']])
    print pearsonr(tmp[:,0], y_test['sadness'])
    ypred += tmp[:,0]
print pearsonr(ypred/7.0, y_test['sadness'])
np.save('sadness1.npy', ypred/7.0)
# Out:
# Epoch 1/20
# 4s - loss: 0.1447 - pearson: 0.4307
# Epoch 2/20
# 4s - loss: 0.1150 - pearson: 0.6592
# Epoch 3/20
# 4s - loss: 0.1031 - pearson: 0.7476
# Epoch 4/20
# 4s - loss: 0.0949 - pearson: 0.8021
# Epoch 5/20
# 4s - loss: 0.0778 - pearson: 0.8718
# Epoch 6/20
# 4s - loss: 0.0656 - pearson: 0.8950
# Epoch 7/20
# 5s - loss: 0.0637 - pearson: 0.9109
# Epoch 8/20
# 5s - loss: 0.0561 - pearson: 0.9293
# Epoch 9/20
# 5s - loss: 0.0552 - pearson: 0.9383
# Epoch 10/20
# 6s - loss: 0.0479 - pearson: 0.9555
# Epoch 11/20
# 6s - loss: 0.0451 - pearson: 0.9559
# Epoch 12/20
# 6s - loss: 0.0431 - pearson: 0.9604
# Epoch 13/20
# 6s - loss: 0.0407 - pearson: 0.9628
# Epoch 14/20
# 6s - loss: 0.0426 - pearson: 0.9621
# Epoch 15/20
# 6s - loss: 0.0395 - pearson: 0.9688
# Epoch 16/20
# 6s - loss: 0.0410 - pearson: 0.9621
# Epoch 17/20
# 6s - loss: 0.0408 - pearson: 0.9691
# Epoch 18/20
# 6s - loss: 0.0381 - pearson: 0.9710
# Epoch 19/20
# 6s - loss: 0.0368 - pearson: 0.9706
# Epoch 20/20
# 6s - loss: 0.0353 - pearson: 0.9717
# (0.74110892291270303, 3.2801322484838479e-118)
# Epoch 1/20
# 4s - loss: 0.1483 - pearson: 0.3689
# Epoch 2/20
# 4s - loss: 0.1219 - pearson: 0.6408
# Epoch 3/20
# 5s - loss: 0.0985 - pearson: 0.7802
# Epoch 4/20
# 6s - loss: 0.0833 - pearson: 0.8415
# Epoch 5/20
# 6s - loss: 0.0736 - pearson: 0.8789
# Epoch 6/20
# 6s - loss: 0.0629 - pearson: 0.9102
# Epoch 7/20
# 7s - loss: 0.0621 - pearson: 0.9274
# Epoch 8/20
# 7s - loss: 0.0535 - pearson: 0.9373
# Epoch 9/20
# 8s - loss: 0.0500 - pearson: 0.9465
# Epoch 10/20
# 8s - loss: 0.0456 - pearson: 0.9562
# Epoch 11/20
# 7s - loss: 0.0468 - pearson: 0.9566
# Epoch 12/20
# 6s - loss: 0.0422 - pearson: 0.9583
# Epoch 13/20
# 6s - loss: 0.0407 - pearson: 0.9629
# Epoch 14/20
# 6s - loss: 0.0390 - pearson: 0.9687
# Epoch 15/20
# 6s - loss: 0.0372 - pearson: 0.9691
# Epoch 16/20
# 7s - loss: 0.0362 - pearson: 0.9729
# Epoch 17/20
# 8s - loss: 0.0360 - pearson: 0.9665
# Epoch 18/20
# 8s - loss: 0.0375 - pearson: 0.9725
# Epoch 19/20
# 8s - loss: 0.0362 - pearson: 0.9755
# Epoch 20/20
# 8s - loss: 0.0341 - pearson: 0.9747
# (0.74164232827857723, 1.8184357100820863e-118)
# Epoch 1/20
# 4s - loss: 0.1472 - pearson: 0.4250
# Epoch 2/20
# 4s - loss: 0.1179 - pearson: 0.6279
# Epoch 3/20
# 4s - loss: 0.1043 - pearson: 0.7365
# Epoch 4/20
# 4s - loss: 0.0921 - pearson: 0.8067
# Epoch 5/20
# 4s - loss: 0.0788 - pearson: 0.8484
# Epoch 6/20
# 4s - loss: 0.0742 - pearson: 0.8798
# Epoch 7/20
# 5s - loss: 0.0628 - pearson: 0.9080
# Epoch 8/20
# 5s - loss: 0.0592 - pearson: 0.9288
# Epoch 9/20
# 5s - loss: 0.0516 - pearson: 0.9402
# Epoch 10/20
# 5s - loss: 0.0573 - pearson: 0.9387
# Epoch 11/20
# 6s - loss: 0.0460 - pearson: 0.9537
# Epoch 12/20
# 8s - loss: 0.0475 - pearson: 0.9488
# Epoch 13/20
# 8s - loss: 0.0465 - pearson: 0.9594
# Epoch 14/20
# 8s - loss: 0.0433 - pearson: 0.9630
# Epoch 15/20
# 8s - loss: 0.0412 - pearson: 0.9648
# Epoch 16/20
# 8s - loss: 0.0428 - pearson: 0.9589
# Epoch 17/20
# 6s - loss: 0.0389 - pearson: 0.9706
# Epoch 18/20
# 6s - loss: 0.0366 - pearson: 0.9691
# Epoch 19/20
# 6s - loss: 0.0383 - pearson: 0.9721
# Epoch 20/20
# 6s - loss: 0.0362 - pearson: 0.9689
# (0.73969953938490529, 1.54803504914318e-117)
# Epoch 1/20
# 4s - loss: 0.1463 - pearson: 0.3569
# Epoch 2/20
# 4s - loss: 0.1190 - pearson: 0.6701
# Epoch 3/20
# 6s - loss: 0.0987 - pearson: 0.7509
# Epoch 4/20
# 6s - loss: 0.0847 - pearson: 0.8343
# Epoch 5/20
# 6s - loss: 0.0784 - pearson: 0.8621
# Epoch 6/20
# 6s - loss: 0.0680 - pearson: 0.8939
# Epoch 7/20
# 7s - loss: 0.0633 - pearson: 0.9188
# Epoch 8/20
# 8s - loss: 0.0581 - pearson: 0.9313
# Epoch 9/20
# 8s - loss: 0.0560 - pearson: 0.9390
# Epoch 10/20
# 8s - loss: 0.0468 - pearson: 0.9458
# Epoch 11/20
# 6s - loss: 0.0445 - pearson: 0.9593
# Epoch 12/20
# 7s - loss: 0.0430 - pearson: 0.9608
# Epoch 13/20
# 9s - loss: 0.0405 - pearson: 0.9667
# Epoch 14/20
# 9s - loss: 0.0392 - pearson: 0.9673
# Epoch 15/20
# 9s - loss: 0.0385 - pearson: 0.9705
# Epoch 16/20
# 9s - loss: 0.0400 - pearson: 0.9710
# Epoch 17/20
# 9s - loss: 0.0373 - pearson: 0.9718
# Epoch 18/20
# 9s - loss: 0.0371 - pearson: 0.9699
# Epoch 19/20
# 9s - loss: 0.0355 - pearson: 0.9725
# Epoch 20/20
# 9s - loss: 0.0348 - pearson: 0.9771
# (0.74871034283044335, 6.3683951287308264e-122)
# Epoch 1/20
# 9s - loss: 0.1404 - pearson: 0.4198
# Epoch 2/20
# 9s - loss: 0.1151 - pearson: 0.6591
# Epoch 3/20
# 5s - loss: 0.0974 - pearson: 0.7850
# Epoch 4/20
# 5s - loss: 0.0818 - pearson: 0.8368
# Epoch 5/20
# 5s - loss: 0.0763 - pearson: 0.8758
# Epoch 6/20
# 6s - loss: 0.0671 - pearson: 0.9042
# Epoch 7/20
# 7s - loss: 0.0628 - pearson: 0.9151
# Epoch 8/20
# 8s - loss: 0.0535 - pearson: 0.9287
# Epoch 9/20
# 8s - loss: 0.0523 - pearson: 0.9484
# Epoch 10/20
# 8s - loss: 0.0488 - pearson: 0.9508
# Epoch 11/20
# 8s - loss: 0.0481 - pearson: 0.9536
# Epoch 12/20
# 8s - loss: 0.0457 - pearson: 0.9564
# Epoch 13/20
# 8s - loss: 0.0441 - pearson: 0.9622
# Epoch 14/20
# 8s - loss: 0.0405 - pearson: 0.9613
# Epoch 15/20
# 9s - loss: 0.0415 - pearson: 0.9646
# Epoch 16/20
# 8s - loss: 0.0395 - pearson: 0.9696
# Epoch 17/20
# 8s - loss: 0.0388 - pearson: 0.9674
# Epoch 18/20
# 8s - loss: 0.0370 - pearson: 0.9719
# Epoch 19/20
# 8s - loss: 0.0362 - pearson: 0.9694
# Epoch 20/20
# 8s - loss: 0.0382 - pearson: 0.9709
# (0.74305270523521261, 3.7951882328978897e-119)
# Epoch 1/20
# 6s - loss: 0.1433 - pearson: 0.4017
# Epoch 2/20
# 6s - loss: 0.1180 - pearson: 0.6615
# Epoch 3/20
# 5s - loss: 0.0993 - pearson: 0.7631
# Epoch 4/20
# 5s - loss: 0.0899 - pearson: 0.8040
# Epoch 5/20
# 6s - loss: 0.0739 - pearson: 0.8758
# Epoch 6/20
# 6s - loss: 0.0647 - pearson: 0.8964
# Epoch 7/20
# 7s - loss: 0.0633 - pearson: 0.9150
# Epoch 8/20
# 7s - loss: 0.0577 - pearson: 0.9316
# Epoch 9/20
# 8s - loss: 0.0512 - pearson: 0.9466
# Epoch 10/20
# 8s - loss: 0.0485 - pearson: 0.9538
# Epoch 11/20
# 8s - loss: 0.0472 - pearson: 0.9562
# Epoch 12/20
# 8s - loss: 0.0426 - pearson: 0.9617
# Epoch 13/20
# 8s - loss: 0.0402 - pearson: 0.9638
# Epoch 14/20
# 8s - loss: 0.0393 - pearson: 0.9691
# Epoch 15/20
# 8s - loss: 0.0386 - pearson: 0.9671
# Epoch 16/20
# 8s - loss: 0.0382 - pearson: 0.9703
# Epoch 17/20
# 9s - loss: 0.0374 - pearson: 0.9728
# Epoch 18/20
# 9s - loss: 0.0370 - pearson: 0.9727
# Epoch 19/20
# 9s - loss: 0.0368 - pearson: 0.9716
# Epoch 20/20
# 9s - loss: 0.0344 - pearson: 0.9735
# (0.74266854801400894, 5.8212999941398186e-119)
# Epoch 1/20
# 6s - loss: 0.1419 - pearson: 0.3935
# Epoch 2/20
# 6s - loss: 0.1213 - pearson: 0.6295
# Epoch 3/20
# 6s - loss: 0.1029 - pearson: 0.7489
# Epoch 4/20
# 6s - loss: 0.0881 - pearson: 0.7976
# Epoch 5/20
# 6s - loss: 0.0753 - pearson: 0.8634
# Epoch 6/20
# 6s - loss: 0.0682 - pearson: 0.9031
# Epoch 7/20
# 7s - loss: 0.0627 - pearson: 0.9151
# Epoch 8/20
# 11s - loss: 0.0540 - pearson: 0.9328
# Epoch 9/20
# 8s - loss: 0.0552 - pearson: 0.9437
# Epoch 10/20
# 9s - loss: 0.0484 - pearson: 0.9511
# Epoch 11/20
# 8s - loss: 0.0466 - pearson: 0.9523
# Epoch 12/20
# 8s - loss: 0.0472 - pearson: 0.9598
# Epoch 13/20
# 8s - loss: 0.0418 - pearson: 0.9658
# Epoch 14/20
# 8s - loss: 0.0398 - pearson: 0.9641
# Epoch 15/20
# 8s - loss: 0.0416 - pearson: 0.9600
# Epoch 16/20
# 9s - loss: 0.0363 - pearson: 0.9722
# Epoch 17/20
# 9s - loss: 0.0383 - pearson: 0.9705
# Epoch 18/20
# 9s - loss: 0.0375 - pearson: 0.9694
# Epoch 19/20
# 9s - loss: 0.0350 - pearson: 0.9759
# Epoch 20/20
# 9s - loss: 0.0353 - pearson: 0.9719
# (0.74555474854882753, 2.2961945079093895e-120)
# (0.75877355806090729, 4.7788012776969483e-127)

# %% [markdown]
# ## fear
